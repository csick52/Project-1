# %%
import json
import requests

api_key = "eaaf48cf6cca4f9b8864b54d123a0dfa"

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import pprint

client_credentials_manager = SpotifyClientCredentials("eaaf48cf6cca4f9b8864b54d123a0dfa", "a5b1db7be8d044aa8511b66aa2a1e901")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

search_str = 'Muse'
result = sp.search(search_str)
pprint.pprint(result)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Muse&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12Chz98pHFMPJEknJQMWvI'},
#                                               'href': 'https://api.spotify.com/v1/artists/12Chz98pHFMPJEknJQMWvI',
#                                               'id': '12Chz98pHFMPJEknJQMWvI',
#                                               'name': 'Muse',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:12Chz98pHFMPJEknJQMWvI'}],
#                                  'available_markets': ['AD',
#                                                        'AR',
#                                                        'AT',
#                                                        'AU',
# ...

# %%
import spotipy
import spotipy.oauth2

credentials = spotipy.oauth2.SpotifyClientCredentials("eaaf48cf6cca4f9b8864b54d123a0dfa", "a5b1db7be8d044aa8511b66aa2a1e901")
spotify = spotipy.Spotify(client_credentials_manager=credentials)
print(spotify.audio_features(['4uLU6hMCjMI75M1A2tKUQC']))

print(json.dumps(spotify.audio_features(['4uLU6hMCjMI75M1A2tKUQC']), indent=4, sort_keys=True))
# Out:
# [{'danceability': 0.721, 'energy': 0.939, 'key': 8, 'loudness': -11.823, 'mode': 1, 'speechiness': 0.0376, 'acousticness': 0.115, 'instrumentalness': 3.79e-05, 'liveness': 0.108, 'valence': 0.914, 'tempo': 113.309, 'type': 'audio_features', 'id': '4uLU6hMCjMI75M1A2tKUQC', 'uri': 'spotify:track:4uLU6hMCjMI75M1A2tKUQC', 'track_href': 'https://api.spotify.com/v1/tracks/4uLU6hMCjMI75M1A2tKUQC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uLU6hMCjMI75M1A2tKUQC', 'duration_ms': 213573, 'time_signature': 4}]
# [
#     {
#         "acousticness": 0.115,
#         "analysis_url": "https://api.spotify.com/v1/audio-analysis/4uLU6hMCjMI75M1A2tKUQC",
#         "danceability": 0.721,
#         "duration_ms": 213573,
#         "energy": 0.939,
#         "id": "4uLU6hMCjMI75M1A2tKUQC",
#         "instrumentalness": 3.79e-05,
#         "key": 8,
#         "liveness": 0.108,
#         "loudness": -11.823,
#         "mode": 1,
#         "speechiness": 0.0376,
# ...

# %%
x = spotify.user_playlist_tracks("37i9dQZF1DX8a1tdzq5tbM", playlist_id="37i9dQZF1DWWEJlAGA9gs0", fields=None, limit=100, offset=0, market=None)

# %%
print(json.dumps(x, indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b4d2ac013ae9> in <module>()
# ----> 1 print(json.dumps(x, indent=4, sort_keys=True))
#
# NameError: name 'x' is not defined

# %%
import spotipy
import spotipy.oauth2

credentials = spotipy.oauth2.SpotifyClientCredentials("eaaf48cf6cca4f9b8864b54d123a0dfa", "a5b1db7be8d044aa8511b66aa2a1e901")
spotify = spotipy.Spotify(client_credentials_manager=credentials)
print(spotify.audio_features(['4uLU6hMCjMI75M1A2tKUQC']))

print(json.dumps(spotify.audio_features(['4uLU6hMCjMI75M1A2tKUQC']), indent=4, sort_keys=True))
