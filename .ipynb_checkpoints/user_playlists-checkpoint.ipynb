# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Credentials
from keys import client_id
from keys import client_secret
#client_id=es_client_id
#client_secret=es_client_secret

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Get List of Playlists for Specified User
user="spotify"

playlist_names=[]
playlist_ids=[]

playlists = sp.user_playlists(user, limit=10)
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
        playlist_names.append(playlist['name'])
        playlist_ids.append(playlist['id'])
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None
    break
# Out:
#    1 spotify:user:spotify:playlist:37i9dQZF1DXcBWIGoYBM5M Today's Top Hits
#    2 spotify:user:spotify:playlist:37i9dQZF1DX0XUsuxWHRQd RapCaviar
#    3 spotify:user:spotify:playlist:37i9dQZF1DX4dyzvuaRJ0n mint
#    4 spotify:user:spotify:playlist:37i9dQZF1DX4SBhb3fqCJd Are & Be
#    5 spotify:user:spotify:playlist:37i9dQZF1DXcF6B6QPhFDv Rock This
#    6 spotify:user:spotify:playlist:37i9dQZF1DX1lVhptIYRda Hot Country
#    7 spotify:user:spotify:playlist:37i9dQZF1DX10zKzsJ2jva ¡Viva Latino!
#    8 spotify:user:spotify:playlist:37i9dQZF1DX4JAvHpjipBk New Music Friday
#    9 spotify:user:spotify:playlist:37i9dQZF1DX4E3UdUs7fUx Afternoon Acoustic
#   10 spotify:user:spotify:playlist:37i9dQZF1DX4sWSpwq3LiO Peaceful Piano

# %%
playlist_id=playlist_ids[0]

track_ids=[]
track_names=[]

tracks = sp.user_playlist_tracks(user, playlist_id, limit=50)

for i in range(len(tracks['items'])):
    print(" ID: " + tracks['items'][i]['track']['id'] + ": " + tracks['items'][i]['track']['name'])
    track_ids.append(tracks['items'][i]['track']['id'])
    track_names.append(tracks['items'][i]['track']['name'])
# Out:
#  ID: 6Qs4SXO9dwPj5GKvVOv8Ki: Dancing With A Stranger (with Normani)
#  ID: 5p7ujcrUXASCNwRaWNHR1C: Without Me
#  ID: 6MWtB6iiXyIwun0YzU6DFP: Wow.
#  ID: 7wFybC8jBH3zE139OpCtpG: Lost in the Fire (feat. The Weeknd)
#  ID: 7vGGAJBkHKxKtOnGjQduDV: Saturday Nights
#  ID: 3Ol2xnObFdKV9pmRD2t9x8: Look Back At It
#  ID: 4BiiOzZCrXEzHRLYcYFiD5: Hope
#  ID: 1rqqCSm0Qe4I9rUvWncaom: High Hopes
#  ID: 1A6OTy97kk0mMdm78rHsm8: Sunflower - Spider-Man: Into the Spider-Verse
#  ID: 5JEx7HbmvHQQswJCsoo9rA: Close To Me (with Diplo) (feat. Swae Lee)
#  ID: 0lsRatBUs9HNIZAmoGABzk: Trampoline
#  ID: 6GzApXoBQiiAjak3tOQfV3: Lie To Me (feat. Julia Michaels)
#  ID: 25sgk305KZfyuqVBQIahim: Sweet but Psycho
#  ID: 5itOtNx0WxtJmi1TQ3RuRd: Giant (with Rag'n'Bone Man)
#  ID: 27rdGxbavYJeBphck5MZAF: Nothing Breaks Like a Heart (feat. Miley Cyrus)
#  ID: 14JzyD6FlBD5z0wV5P07YI: when the party's over
#  ID: 2IRZnDFmlqMuOrYOLnZZyc: Going Bad (feat. Drake)
#  ID: 2rPE9A1vEgShuZxxzR2tZH: thank u, next
#  ID: 2RSHsoi04658QL5xgQVov3: Bad Liar
#  ID: 5iwz1NiezX7WWjnCgY5TH4: Calma - Remix
#  ID: 2LskIZrCeLxRvCiGP8gxlh: Arms Around You (feat. Maluma & Swae Lee)
#  ID: 2qxmye6gAegTMjLKEBoR3d: Let Me Down Slowly
#  ID: 0PowxVSTY2uh1CPc8EPKyX: Project Dreams
#  ID: 0todbbT9g5uQGbeFCiBf2F: imagine
#  ID: 4Uy3kNxW2kB8AEoXljEcth: Familia (with Anuel Aa, feat. Bantu) - Spider-Man: Into the Spider-Verse
#  ID: 5rFj8OzffT0iggSjcBaeND: Fire On Fire - From "Watership Down"
#  ID: 78nplE9X2ZGvQh3TKgvldE: Rewrite The Stars (with James Arthur & Anne-Marie)
#  ID: 1KVczjazCcCCgM3gXXUl47: Roses (with Juice WRLD feat. Brendon Urie)
#  ID: 7FjZU7XFs7P9jHI9Z0yRhK: So Close
#  ID: 5tAa8Uaqr4VvA3693mbIhU: Ruin My Life
#  ID: 2TIlqbIneP0ZY1O0EzYLlc: Someone You Loved
#  ID: 7jr3iPu4O4bTCVwLMbdU2i: Kiss and Make Up
#  ID: 1tT55K6VEyO6XFDxK4lDQe: In My Head
#  ID: 6FyRXC8tJUh863JCkyWqtk: Adan y Eva
#  ID: 3WefHNGtjexZvi66ZEx9u4: Hurts Like Hell (feat. Offset)
#  ID: 2FUNBaa5DwItJtYEBgAblU: monster
#  ID: 6QfS2wq5sSC1xAJCQsTSlj: Shallow - Radio Edit
#  ID: 7lAK3oHbfEnvUQWosrMMpR: YOSEMITE
#  ID: 2YyvWje3cEYyqgYhNUIaBJ: La Di Da
#  ID: 5YOkA7qd2983FtBQnP8sYx: Solo de Mi
#  ID: 1tNJrcVe6gwLEiZCtprs1u: 3 Nights
#  ID: 40eISiXi4QCcczldH5u0n1: There You Are
#  ID: 3gicyfiEVMGONgzygpWjNT: Grip
#  ID: 7l3E7lcozEodtVsSTCkcaA: ZEZE (feat. Travis Scott & Offset)
#  ID: 41zXlQxzTi6cGAjpOXyLYH: idontwannabeyouanymore
#  ID: 4OBZT9EnhYIV17t4pGw7ig: Best Part
#  ID: 7pdF27mSDuPWhppnHAmWHa: whoa (mind in awe)
#  ID: 2wVDWtLKXunswWecARNILj: SOLO
#  ID: 18uwL0vNUanqZH0ro2QcOP: comethru
#  ID: 14mHfNsSHN0FbLftyjrV9g: Leave Me Alone

# %%
#maximum 50 tracks
audio_features=sp.audio_features(track_ids)

# %%
danceability=[]
energy=[]
speechiness=[]
acousticness=[]
instrumentalness=[]
liveness=[]
valence=[]
tempo=[]

for i in range(len(audio_features)):
    danceability.append(audio_features[i]['danceability'])
    energy.append(audio_features[i]['energy'])
    speechiness.append(audio_features[i]['speechiness'])
    acousticness.append(audio_features[i]['acousticness'])
    instrumentalness.append(audio_features[i]['instrumentalness'])
    liveness.append(audio_features[i]['liveness'])
    valence.append(audio_features[i]['valence'])
    tempo.append(audio_features[i]['tempo'])

# %%
tracks_df=pd.DataFrame(track_ids)

for track in range(len(tracks_df)):
    #tracks_df["Track ID"]=track_ids
    tracks_df["Name"]=track_names
    tracks_df["Energy"]=energy
    tracks_df["Danceability"]=danceability
    tracks_df["Speechiness"]=speechiness
    tracks_df["Acousticness"]=acousticness
    tracks_df["Instrumentalness"]=instrumentalness
    tracks_df["Liveness"]=liveness
    tracks_df["Valence"]=valence
    tracks_df["Tempo"]=tempo
    
tracks_df.head()
# Out:
#                         0                                    Name  Energy  \
# 0  6Qs4SXO9dwPj5GKvVOv8Ki  Dancing With A Stranger (with Normani)   0.520
# 1  5p7ujcrUXASCNwRaWNHR1C                              Without Me   0.488
# 2  6MWtB6iiXyIwun0YzU6DFP                                    Wow.   0.539
# 3  7wFybC8jBH3zE139OpCtpG     Lost in the Fire (feat. The Weeknd)   0.675
# 4  7vGGAJBkHKxKtOnGjQduDV                         Saturday Nights   0.439
#
#    Danceability  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0         0.741       0.0656        0.4500          0.000002    0.2220
# 1         0.752       0.0705        0.2970          0.000009    0.0936
# 2         0.833       0.1780        0.1630          0.000002    0.1010
# 3         0.663       0.0359        0.0863          0.001330    0.1170
# 4         0.540       0.1150        0.6350          0.000019    0.0993
#
#    Valence    Tempo
# 0    0.347  102.998
# 1    0.533  136.041
# 2    0.385   99.947
# 3    0.176  101.004
# 4    0.371  167.908

# %%
#Standard Deviation for Audio Properties
sigma1=np.std(energy, axis=None, dtype=None, out=None, ddof=0,)
sigma2=np.std(danceability, axis=None, dtype=None, out=None, ddof=0,)
sigma3=np.std(speechiness, axis=None, dtype=None, out=None, ddof=0,)
sigma4=np.std(acousticness, axis=None, dtype=None, out=None, ddof=0,)
sigma5=np.std(instrumentalness, axis=None, dtype=None, out=None, ddof=0,)
sigma6=np.std(valence, axis=None, dtype=None, out=None, ddof=0,)

#Mean for Audio Properties
mu1=np.mean(energy)
mu2=np.mean(danceability)
mu3=np.mean(speechiness)
mu4=np.mean(acousticness)
mu5=np.mean(instrumentalness)
mu6=np.mean(valence)

# %%
plt.style.use('seaborn') # pretty matplotlib plots
plt.rcParams['figure.figsize'] = (12, 8)


x = np.linspace(0, 1, 5000)

y1 = (1 / (np.sqrt(2 * np.pi * np.power(sigma1, 2)))) * \
    (np.power(np.e, -(np.power((x - mu1), 2) / (2 * np.power(sigma1, 2)))))

y2 = (1 / (np.sqrt(2 * np.pi * np.power(sigma2, 2)))) * \
    (np.power(np.e, -(np.power((x - mu2), 2) / (2 * np.power(sigma2, 2)))))

y3 = (1 / (np.sqrt(2 * np.pi * np.power(sigma3, 2)))) * \
    (np.power(np.e, -(np.power((x - mu3), 2) / (2 * np.power(sigma3, 2)))))

y4 = (1 / (np.sqrt(2 * np.pi * np.power(sigma4, 2)))) * \
    (np.power(np.e, -(np.power((x - mu4), 2) / (2 * np.power(sigma4, 2)))))

y5 = (1 / (np.sqrt(2 * np.pi * np.power(sigma5, 2)))) * \
    (np.power(np.e, -(np.power((x - mu5), 2) / (2 * np.power(sigma5, 2)))))

y6 = (1 / (np.sqrt(2 * np.pi * np.power(sigma6, 2)))) * \
    (np.power(np.e, -(np.power((x - mu6), 2) / (2 * np.power(sigma6, 2)))))


energy_plot, =           plt.plot(x,y1, label="energy", linewidth=2)
danceability_plot, =     plt.plot(x,y2, label="danceability", linewidth=2)
speechiness_plot, =      plt.plot(x,y3, label="speechiness", linewidth=2)
acousticness_plot, =     plt.plot(x,y4, label="acousticness", linewidth=2)
instrumentalness_plot, = plt.plot(x,y5, label="instrumentalness", linewidth=2)
valence_plot, =          plt.plot(x,y6, label="valence", linewidth=2)

plt.vlines(mu1, 0, np.max(y1), colors='grey', linestyles='dashed', label='', )
plt.vlines(mu2, 0, np.max(y2), colors='grey', linestyles='dashed', label='', )
plt.vlines(mu3, 0, np.max(y3), colors='grey', linestyles='dashed', label='', )
plt.vlines(mu4, 0, np.max(y4), colors='grey', linestyles='dashed', label='', )
plt.vlines(mu5, 0, np.max(y5), colors='grey', linestyles='dashed', label='', )
plt.vlines(mu6, 0, np.max(y6), colors='grey', linestyles='dashed', label='', )

plt.annotate('X=%.2f'%mu1, xy=(mu1, np.max(y1)), fontsize=15)
plt.annotate('X=%.2f'%mu2, xy=(mu2, np.max(y2)), fontsize=15)
plt.annotate('X=%.2f'%mu3, xy=(mu3, np.max(y3)), fontsize=15)
plt.annotate('X=%.2f'%mu4, xy=(mu4, np.max(y4)), fontsize=15)
plt.annotate('X=%.2f'%mu5, xy=(mu5, np.max(y5)), fontsize=15)
plt.annotate('X=%.2f'%mu6, xy=(mu6, np.max(y6)), fontsize=15)

plt.title("Mean Audio Property Values", fontsize=20)
plt.xlabel("Audio Property Value (0 < x < 1.0)", fontsize=15)
plt.ylabel("Probability of Occurence", fontsize=15)

plt.legend(fontsize='x-large')
